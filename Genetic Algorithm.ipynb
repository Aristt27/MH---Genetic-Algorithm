# %%
### Imports

from GA_import_csv_instance import instancia_csv
from GA_objective_function import funcao_objetivo
from GA_solution_breakdown import sol_bd
from GA_genetic_algorithm import Genetic_Algorithm

# %%
instancia_1 = instancia_csv("instances/f1_toy1.csv")
# Out:
# Carregando Arquivo CSV instances/f1_toy1.csv
# ['Cirurgia (c)', 'Prioridade (p)', 'Dias de espera (w)', 'Especialidade (e)', 'Cirurgião (g)', 'Duração (tc)']

# %%
pop_inicial = 1000
gen_cut     = 15
LimitDay    = 5        ## Arrumar esse tal de LimitDay...
Rooms       = 1
generations = 2
children    = 2

## Parametros do crossover
α  = 0.5 # probabilidade

## Parametros da mutação

default_params = [pop_inicial, gen_cut, LimitDay, Rooms, generations, α, children]

# %%
Genetic_Algorithm(instancia_1, funcao_objetivo, default_params)
# Out:
# A população inicial é de 1000
#
# Ou seja, teremos como os ancestrais(High Scores) os seguintes, tendo em vista que gen_cut = 15
#
# [[1, 1, 3], [1, 1, 7], [2, 1, 5], [1, 1, 4], [2, 1, 4], [2, 1, 1], [1, 1, 5], [2, 1, 6]] 77265 1515
# [[1, 1, 8], [1, 1, 1], [1, 1, 3], [2, 1, 6], [2, 1, 6], [1, 1, 5], [2, 1, 8], [2, 1, 9]] 77163 1513
# [[1, 1, 7], [2, 1, 4], [1, 1, 7], [1, 1, 1], [2, 1, 5], [1, 1, 8], [2, 1, 1], [2, 1, 1]] 77163 1513
# [[1, 1, 5], [1, 1, 8], [1, 1, 3], [2, 1, 4], [2, 1, 7], [1, 1, 1], [2, 1, 9], [2, 1, 6]] 77163 1513
# [[1, 1, 8], [1, 1, 8], [2, 1, 8], [1, 1, 5], [1, 1, 4], [2, 1, 3], [2, 1, 9], [2, 1, 7]] 77061 1511
# [[1, 1, 6], [1, 1, 2], [2, 1, 5], [1, 1, 6], [1, 1, 2], [2, 1, 8], [2, 1, 9], [2, 1, 1]] 77061 1511
# [[1, 1, 1], [1, 1, 3], [2, 1, 5], [1, 1, 3], [1, 1, 4], [2, 1, 7], [2, 1, 2], [2, 1, 4]] 77061 1511
# [[2, 1, 6], [3, 1, 1], [2, 1, 8], [3, 1, 6], [1, 1, 9], [1, 1, 3], [1, 1, 1], [1, 1, 9]] 56298 56298
# ...

# %% [markdown]
# ## Como usar a estrutura de dados pra representar o que a gente quer?
#
# Observe que podemos considerar uma árvore para a estrutura de dados.
