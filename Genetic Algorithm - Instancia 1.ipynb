# %%
### Imports

from GA_import_csv_instance import instancia_csv
from GA_objective_function import funcao_objetivo
from GA_solution_breakdown import sol_bd
from GA_genetic_algorithm import Genetic_Algorithm, fitness
from GA_evolution_statistical_analysis import evolution_statistical_analysis

# %%
instancia = instancia_csv("instances/i1.csv")
# Out:
# Carregando Arquivo CSV instances/i1.csv
# ['Cirurgia (c)', 'Prioridade (p)', 'Dias_espera (w)', 'Especialidade (e)', 'Cirurgião (h)', 'Duração (tc)']
# # randomFit_r2_s15_t8-4
# # RandomFit: Escala três urgências para cada sala
# # 2 salas. 15 cirurgias (6 urgencias)
# # Duração das cirurgias segundo distribuição normal com media 8 e desvio 4 (minimo e 2 e maximo 22)
# # Todas as cirurgias de prioridade 1 cabem no dia 1

# %%
pop_inicial = 4000
elite_cut   = 0.1
lucky_cut  = 0.2
LimitDay    = 5       ## ...
Rooms       = 2
generations = 100


Instancia = (instancia, Rooms)
## Parametros do crossover
α        = 0.5 # probabilidade
cut_type = "ONE_CUT" # tipo de corte
## Parametros do offspringer
children    = 500

## Parametros da mutação
β = 0.15 # Probabilidade de escolher tal filho para mutar;

default_params = [pop_inicial, elite_cut, lucky_cut, LimitDay, generations, α, cut_type, children, β]

## Criterios de parada:
#generations -> iterações
stop_len = 7 # quantas iterações seguias a media das K melhores tem q estar a uma distancia tol para parar
K        = 15
tol      = 1

stop_criteria = [stop_len, K, tol]

# %%
# %time GA = Genetic_Algorithm(Instancia, funcao_objetivo, default_params, stop_criteria, Verbose = False)

avgs, bests = evolution_statistical_analysis(GA, fitness, (Instancia, funcao_objetivo), Verbose = False)

print(" ")
print('A solução tem valor')
print(min(bests))
# Out:
#
#  Algoritmo encerrou devido ao criterio de parada mágico
#
# CPU times: user 31.9 s, sys: 93.5 ms, total: 32 s
# Wall time: 32 s
#
#  O Algoritmo levou 47 iterações.
#
#
# A solução tem valor
# 260788.0

# %%
# %time GA1 = Genetic_Algorithm(Instancia, funcao_objetivo, default_params, stop_criteria, Verbose = False)

avgs, bests = evolution_statistical_analysis(GA1, fitness, (Instancia, funcao_objetivo), Verbose = False)

print(" ")
print('A solução tem valor')
print(min(bests))
# Out:
#
#  Algoritmo encerrou devido ao criterio de parada mágico
#
# CPU times: user 20.6 s, sys: 24.1 ms, total: 20.6 s
# Wall time: 20.6 s
#
#  O Algoritmo levou 29 iterações.
#
#
# A solução tem valor
# 260827.0

# %%
# %time GA2 = Genetic_Algorithm(Instancia, funcao_objetivo, default_params, stop_criteria, Verbose = False)

avgs, bests = evolution_statistical_analysis(GA2, fitness, (Instancia, funcao_objetivo), Verbose = False)

print(" ")
print('A solução tem valor')
print(min(bests))
# Out:
#
#  Algoritmo encerrou devido ao criterio de parada mágico
#
# CPU times: user 17.9 s, sys: 3.97 ms, total: 17.9 s
# Wall time: 17.9 s
#
#  O Algoritmo levou 23 iterações.
#
#
# A solução tem valor
# 260827.0

# %%
# %time GA3 = Genetic_Algorithm(Instancia, funcao_objetivo, default_params, stop_criteria, Verbose = False)

avgs, bests = evolution_statistical_analysis(GA3, fitness, (Instancia, funcao_objetivo), Verbose = False)

print(" ")
print('A solução tem valor')
print(min(bests))
# Out:
#
#  Algoritmo encerrou devido ao criterio de parada mágico
#
# CPU times: user 18.4 s, sys: 12 ms, total: 18.4 s
# Wall time: 18.4 s
#
#  O Algoritmo levou 26 iterações.
#
#
# A solução tem valor
# 260877.0

# %%
# %time GA4 = Genetic_Algorithm(Instancia, funcao_objetivo, default_params, stop_criteria, Verbose = False)

avgs, bests = evolution_statistical_analysis(GA4, fitness, (Instancia, funcao_objetivo), Verbose = False)

print(" ")
print('A solução tem valor')
print(min(bests))
# Out:
#
#  Algoritmo encerrou devido ao criterio de parada mágico
#
# CPU times: user 15.3 s, sys: 7.99 ms, total: 15.3 s
# Wall time: 15.3 s
#
#  O Algoritmo levou 22 iterações.
#
#
# A solução tem valor
# 260921.0
