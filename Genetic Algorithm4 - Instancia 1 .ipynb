# %%
### Imports

from GA_import_csv_instance import instancia_csv
from GA_objective_function import funcao_objetivo
from GA_solution_breakdown import sol_bd
from GA_genetic_algorithm import Genetic_Algorithm, fitness
from GA_evolution_statistical_analysis import evolution_statistical_analysis

# %%
instancia = instancia_csv("instances/i1.csv")
# Out:
# Carregando Arquivo CSV instances/i1.csv
# ['Cirurgia (c)', 'Prioridade (p)', 'Dias_espera (w)', 'Especialidade (e)', 'Cirurgião (h)', 'Duração (tc)']
# # randomFit_r2_s15_t8-4
# # RandomFit: Escala três urgências para cada sala
# # 2 salas. 15 cirurgias (6 urgencias)
# # Duração das cirurgias segundo distribuição normal com media 8 e desvio 4 (minimo e 2 e maximo 22)
# # Todas as cirurgias de prioridade 1 cabem no dia 1

# %%
pop_inicial = 1000
elite_cut   = 0.1
lucky_cut  = 0.3
LimitDay    = 5        
Rooms       = 2
generations = 1000


Instancia = (instancia, Rooms)
## Parametros do crossover
cut_type = "ONE_CUT" # tipo de corte

## Parametros da mutação
β = 0.2 # Probabilidade de escolher tal filho para mutar;

default_params = [pop_inicial, elite_cut, lucky_cut, LimitDay, generations, cut_type, β]

## Criterios de parada:
#generations -> iterações
stop_len = 15 # quantas iterações seguias a media das K melhores tem q estar a uma distancia tol para parar
K        = 100
tol      = 1

stop_criteria = [stop_len, K, tol]

# %%
# %time GA = Genetic_Algorithm(Instancia, funcao_objetivo, default_params, stop_criteria, Verbose = False)

avgs, bests = evolution_statistical_analysis(GA, fitness, (Instancia, funcao_objetivo), cut = 100 ,Verbose = False)

print(" ")
print('A solução tem valor')
print(min(bests))
# Out:
#
#  Algoritmo encerrou devido ao criterio de parada mágico
#
# CPU times: user 12.1 s, sys: 12.8 ms, total: 12.1 s
# Wall time: 12.1 s
#
#  O Algoritmo levou 87 iterações.
#
#
# A solução tem valor
# 261164.0

# %%
# %time GA = Genetic_Algorithm(Instancia, funcao_objetivo, default_params, stop_criteria, Verbose = False)

avgs, bests = evolution_statistical_analysis(GA, fitness, (Instancia, funcao_objetivo), cut = 100 ,Verbose = False)

print(" ")
print('A solução tem valor')
print(min(bests))
# Out:
#
#  Algoritmo encerrou devido ao criterio de parada mágico
#
# CPU times: user 9.23 s, sys: 0 ns, total: 9.23 s
# Wall time: 9.23 s
#
#  O Algoritmo levou 59 iterações.
#
#
# A solução tem valor
# 260788.0

# %%
# %time GA = Genetic_Algorithm(Instancia, funcao_objetivo, default_params, stop_criteria, Verbose = False)

avgs, bests = evolution_statistical_analysis(GA, fitness, (Instancia, funcao_objetivo), cut = 100 ,Verbose = False)

print(" ")
print('A solução tem valor')
print(min(bests))
# Out:
#
#  Algoritmo encerrou devido ao criterio de parada mágico
#
# CPU times: user 3.1 s, sys: 0 ns, total: 3.1 s
# Wall time: 3.1 s
#
#  O Algoritmo levou 21 iterações.
#
#
# A solução tem valor
# 262259.0

# %%
# %time GA = Genetic_Algorithm(Instancia, funcao_objetivo, default_params, stop_criteria, Verbose = False)

avgs, bests = evolution_statistical_analysis(GA, fitness, (Instancia, funcao_objetivo), cut = 100 ,Verbose = False)

print(" ")
print('A solução tem valor')
print(min(bests))
# Out:
#
#  Algoritmo encerrou devido ao criterio de parada mágico
#
# CPU times: user 5.01 s, sys: 0 ns, total: 5.01 s
# Wall time: 5.01 s
#
#  O Algoritmo levou 31 iterações.
#
#
# A solução tem valor
# 262259.0

# %%
# %time GA = Genetic_Algorithm(Instancia, funcao_objetivo, default_params, stop_criteria, Verbose = False)

avgs, bests = evolution_statistical_analysis(GA, fitness, (Instancia, funcao_objetivo), cut = 100 ,Verbose = False)

print(" ")
print('A solução tem valor')
print(min(bests))
# Out:
#
#  Algoritmo encerrou devido ao criterio de parada mágico
#
# CPU times: user 7.83 s, sys: 7.23 ms, total: 7.84 s
# Wall time: 7.83 s
#
#  O Algoritmo levou 55 iterações.
#
#
# A solução tem valor
# 260996.0

# %%
# %prun Genetic_Algorithm(Instancia, funcao_objetivo, default_params, stop_criteria, Verbose = False)
# Out:
#
#  Algoritmo encerrou devido ao criterio de parada mágico
